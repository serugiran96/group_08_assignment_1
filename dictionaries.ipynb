# %% [markdown]
# # Part 3 – Dictionaries

# %%
population = {
    "Lima": 10092000,
    "Arequipa": 1008000,
    "Trujillo": 919000
}

print(population)
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Trujillo': 919000}

# %% [markdown]
# ## 2. Display the keys

# %%
print(population.keys())
# Out:
# dict_keys(['Lima', 'Arequipa', 'Trujillo'])

# %% [markdown]
# ## 3. Get the population of Lima

# %%
print(population.get("Lima"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(population.get("Lima"))
#
# NameError: name 'population' is not defined

# %%
population = {
    "Lima": 10092000,
    "Arequipa": 1008000,
    "Trujillo": 919000
}

print(population)
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Trujillo': 919000}

# %%
print(population.keys())
# Out:
# dict_keys(['Lima', 'Arequipa', 'Trujillo'])

# %%
print(population.get("Lima"))
# Out:
# 10092000

# %%
population["Cusco"] = 428000

# %%
population["Cusco"] = 428000
print(population)
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Trujillo': 919000, 'Cusco': 428000}

# %%
population.pop("Trujillo")
# Out:
# 919000

# %%
print(population)
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Cusco': 428000}

# %%
print(population)
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Cusco': 428000}
